# %%
#1. Lire le fichier

import pandas as pd

netflix = pd.read_csv ('/home/simplon/Documents/Cours hebdomadaire/Semaine 8/Python/netflix_titles.csv', index_col=0)
netflix.head(5)
# Out:
#              type                                    title  \
# show_id
# 81145628    Movie  Norm of the North: King Sized Adventure
# 80117401    Movie               Jandino: Whatever it Takes
# 70234439  TV Show                       Transformers Prime
# 80058654  TV Show         Transformers: Robots in Disguise
# 80125979    Movie                             #realityhigh
#
#                           director  \
# show_id
# 81145628  Richard Finn, Tim Maltby
# 80117401                       NaN
# 70234439                       NaN
# 80058654                       NaN
# 80125979          Fernando Lebrija
#
#                                                        cast  \
# show_id
# 81145628  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 80117401                                   Jandino Asporaat
# 70234439  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 80058654  Will Friedle, Darren Criss, Constance Zimmer, ...
# ...

# %%
#2. Afficher les dimensions du dataframe

# dataframe.size
size = netflix.size 
# dataframe.shape 
shape = netflix.shape 

# printing size et shape 
print("Size = {}\nShape ={}\nShape[0] x Shape[1] = {}". 
format(size, shape, shape[0]*shape[1])) 
print("")

print("Le jeu de donnees a", netflix.shape[0], "films avec ", netflix.shape[1], "variables.")
# Out:
# Size = 68574
# Shape =(6234, 11)
# Shape[0] x Shape[1] = 68574
#
# Le jeu de donnees a 6234 films avec  11 variables.

# %%
#3. Compter les films et les séries

fs = netflix['type'].value_counts()
fs
# Out:
# Movie      4265
# TV Show    1969
# Name: type, dtype: int64

# %%
#4. Générer le résumé statistique du dataframe

netflix.describe(include='all')
# Out:
#          type   title                director                cast  \
# count    6234    6234                    4265                5664
# unique      2    6172                    3301                5469
# top     Movie  Tunnel  Raúl Campos, Jan Suter  David Attenborough
# freq     4265       3                      18                  18
# mean      NaN     NaN                     NaN                 NaN
# std       NaN     NaN                     NaN                 NaN
# min       NaN     NaN                     NaN                 NaN
# 25%       NaN     NaN                     NaN                 NaN
# 50%       NaN     NaN                     NaN                 NaN
# 75%       NaN     NaN                     NaN                 NaN
# max       NaN     NaN                     NaN                 NaN
#
#               country       date_added  release_year rating  duration  \
# count            5758             6223    6234.00000   6224      6234
# ...

# %%
#5. Compter les valeurs manquantes

netflix.isna().sum()
# Out:
# type               0
# title              0
# director        1969
# cast             570
# country          476
# date_added        11
# release_year       0
# rating            10
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %%
#6. Explorer les valeurs manquantes
#a Sur la colonne des directeurs de production

vmd = netflix.loc[netflix['director'].isna()]
vmd.loc[:,'type'].value_counts()
# Out:
# TV Show    1841
# Movie       128
# Name: type, dtype: int64

# %%
#b. Sur la colonne des acteurs

vmc = netflix.loc[netflix['cast'].isna()]
vmc['listed_in'].value_counts().head(10)
# Out:
# Documentaries                                         148
# Documentaries, International Movies                    94
# Docuseries                                             31
# Documentaries, Sports Movies                           20
# Crime TV Shows, Docuseries                             19
# Documentaries, Music & Musicals                        15
# Docuseries, International TV Shows                     14
# Kids' TV                                               14
# Documentaries, International Movies, Sports Movies     14
# Crime TV Shows, Docuseries, International TV Shows     12
# Name: listed_in, dtype: int64

# %%
#7. Supprimer les lignes dupliquées

dup = netflix.duplicated()
print(dup.value_counts())
# Out:
# False    6233
# True        1
# dtype: int64

# %%
#7. Supprimer les lignes dupliquées

netflix = netflix.drop_duplicates(keep='last')
netflix.head(4)
# Out:
#              type                                    title  \
# show_id
# 81145628    Movie  Norm of the North: King Sized Adventure
# 80117401    Movie               Jandino: Whatever it Takes
# 70234439  TV Show                       Transformers Prime
# 80058654  TV Show         Transformers: Robots in Disguise
#
#                           director  \
# show_id
# 81145628  Richard Finn, Tim Maltby
# 80117401                       NaN
# 70234439                       NaN
# 80058654                       NaN
#
#                                                        cast  \
# show_id
# 81145628  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 80117401                                   Jandino Asporaat
# 70234439  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 80058654  Will Friedle, Darren Criss, Constance Zimmer, ...
#
#                                            country         date_added  \
# show_id
# ...

# %%
#8. Compter les films/séries produits par les États-Unis et par la France

filmus = netflix.loc[netflix.country == 'United States', 'title']
print(filmus)

filmfr = netflix.loc[netflix.country == 'France', 'title']
print(filmfr)
# Out:
# show_id
# 70234439                  Transformers Prime
# 80058654    Transformers: Robots in Disguise
# 80125979                        #realityhigh
# 80117902                        Fire Chasers
# 80060297                   Manhattan Romance
#                           ...
# 70153412                             Frasier
# 70243132                 La Familia P. Luche
# 80000063                        Red vs. Blue
# 70286564                               Maron
# 70153404                             Friends
# Name: title, Length: 2032, dtype: object
# show_id
# 80178151                  The Spy
# 70153543              Sarah's Key
# 80217779                 Marianne
# 81005314                 Sparring
# 80160358                    Rocco
#                     ...
# 80097771    A Very Secret Service
# 80133335           Call My Agent!
# 80037278                Marseille
# 80003196                    Wakfu
# 80231523      The Minimighty Kids
# Name: title, Length: 90, dtype: object

# %%
#9. Afficher le contenu le plus vieux disponible sur Netflix

netflix.min()
# Out:
# type                                                        Movie
# title                                                       #Roxy
# release_year                                                 1925
# duration                                                 1 Season
# listed_in                                      Action & Adventure
# description     "Brooklyn Nine-Nine" star Chelsea Peretti show...
# dtype: object

# %%
netflix.loc[netflix["release_year"] == 1925, :]
# Out:
#              type                              title director cast country  \
# show_id
# 81030762  TV Show  Pioneers: First Women Filmmakers*      NaN  NaN     NaN
#
#                  date_added  release_year rating  duration listed_in  \
# show_id
# 81030762  December 30, 2018          1925  TV-PG  1 Season  TV Shows
#
#                                                 description
# show_id
# 81030762  This collection restores films from women who ...

# %%
#10. Afficher le film avec la durée la plus longue sur Netflix

netflix.movies = netflix.loc[netflix.type == 'Movie']

duree = pd.Series(netflix.movies['duration']).str.replace('min', '').astype('int').sort_values(ascending=False).head(5)
print(duree)
# Out:
# show_id
# 80988062    312
# 60002818    228
# 60020906    224
# 70090035    214
# 80175798    209
# Name: duration, dtype: int64

# %%
#11. Étudier les catégories avec le plus de contenu
       
categories = ", ".join(netflix["director"].dropna())
categories = pd.Series(",".join(netflix["director"].dropna()).split(", "))
categories.value_counts().head()
# Out:
# John Paul Tremblay                5
# Karan Johar                       3
# Lana Wachowski,Lilly Wachowski    2
# Dibakar Banerjee                  2
# Mike Smith                        2
# dtype: int64

# %%
categories = ", ".join(netflix["cast"].dropna())
categories = pd.Series(",".join(netflix["cast"].dropna()).split(", "))
categories.value_counts().head()
# Out:
# Anupam Kher         28
# Om Puri             25
# Takahiro Sakurai    23
# Paresh Rawal        22
# Andrea Libman       21
# dtype: int64
