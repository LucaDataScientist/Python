# %% [markdown]
# # Projet Netflix
# ![modelNetflix]()

# %%
#20. Créez un dataframe nommé « show_listed_in » ayant pour seul colonne « show_id » et « listed_in ».

import pandas as pd
import matplotlib.pyplot as plt
import re

netflix = pd.read_csv ('/home/simplon/Documents/Cours hebdomadaire/Semaine 8/Python/netflix_titles.csv', index_col=0).reset_index()
netflix.head(1)
# Out:
#     show_id   type                                    title  \
# 0  81145628  Movie  Norm of the North: King Sized Adventure
#
#                    director  \
# 0  Richard Finn, Tim Maltby
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
#
#                                     country         date_added  release_year  \
# 0  United States, India, South Korea, China  September 9, 2019          2019
#
#   rating duration                           listed_in  \
# 0  TV-PG   90 min  Children & Family Movies, Comedies
#
#                                          description
# 0  Before planning an awesome wedding for his gra...

# %%
netflix.loc[[5550]]
# Out:
#        show_id   type            title          director  \
# 5550  80131414  Movie  Born to Be Free  Gayane Petrosyan
#
#                                                    cast  \
# 5550  Casting a light on the mistreatment of sea mam...
#
#                      country     date_added  release_year rating duration  \
# 5550  United Kingdom, Russia  April 1, 2017          2016  TV-14   74 min
#
#                                 listed_in  \
# 5550  Documentaries, International Movies
#
#                                             description
# 5550  Casting a light on the mistreatment of sea mam...

# %%
netflix.loc[5550, 'cast']=''

# %%
netflix.loc

# %%
# On crée le DataFrame show_listed en précisant ses colonnes
# Il sera utilisé à la fin de la partie 3 pour remplir la table côté MySQL 
# qui fait la liaison entre le catalogue et les catégories
donneesAvecCategories = netflix[netflix['listed_in'].notna()][['show_id', 'listed_in']]
show_listed_in = pd.DataFrame(columns = ['show_id','listed_in'])

# Pour chaque ligne (film ou série) i du DataFrame
for i in donneesAvecCategories.index:
    # On récupère toutes les catégories que l'on sépare dans une liste
    categoriesFilm = donneesAvecCategories["listed_in"][i].split(", ") 
    # On crée une liste de même longueur (len(categoriesFilm)) remplie par l'identifiant show_id
    # ex pour créer une liste : ["toto"] * 3 crée la liste ["toto, "toto", "toto"]
    idFilm = [donneesAvecCategories["show_id"][i]] * len(categoriesFilm)
    # On crée un Dataframe df temporaire qui fusionne les 2 listes qu'on vient de créer
    df = pd.DataFrame({'show_id': idFilm,'listed_in': categoriesFilm})
    # On colle ce Dataframe temporaire à show-listed_in
    show_listed_in = show_listed_in.append(df, ignore_index = True)
    
# show_listed_in contient tous les DataFrames temporaires qu'on a créés à chaque ligne       
show_listed_in
# Out:
#         show_id                 listed_in
# 0      81145628  Children & Family Movies
# 1      81145628                  Comedies
# 2      80117401           Stand-Up Comedy
# 3      70234439                  Kids' TV
# 4      80058654                  Kids' TV
# ...         ...                       ...
# 13665  70281022          British TV Shows
# 13666  70281022               TV Comedies
# 13667  70281022                 TV Dramas
# 13668  70153404         Classic & Cult TV
# 13669  70153404               TV Comedies
#
# [13670 rows x 2 columns]

# %%
#21. Créez un dataframe nommé « listed_in » ayant pour colonne « listed_in_id » et « listed_in ».
#correction

# On crée le DataFrame listed_in avec ses colonnes
listed_in = pd.DataFrame(columns = ['listed_in_id','listed_in'])
# On met dans listed_in toutes les valeurs différentes de catégories
listed_in['listed_in'] = show_listed_in['listed_in'].drop_duplicates()
# On supprime l'index actuel
listed_in.reset_index(drop= True, inplace = True)
# On met dans listed_in_id le nouvel index + 1 
# car, côté MySQL, la clé primaire commence à 1 s'il y a auto incrémentation
listed_in['listed_in_id'] = listed_in.index + 1
listed_in
# Out:
#     listed_in_id                     listed_in
# 0              1      Children & Family Movies
# 1              2                      Comedies
# 2              3               Stand-Up Comedy
# 3              4                      Kids' TV
# 4              5                Crime TV Shows
# 5              6        International TV Shows
# 6              7     Spanish-Language TV Shows
# 7              8          International Movies
# 8              9              Sci-Fi & Fantasy
# 9             10                     Thrillers
# 10            11                    Docuseries
# 11            12           Science & Nature TV
# 12            13            Action & Adventure
# 13            14                        Dramas
# 14            15                   Cult Movies
# 15            16            Independent Movies
# 16            17               Romantic Movies
# 17            18                 Documentaries
# 18            19                 Horror Movies
# ...

# %%
show_listed_in = show_listed_in.merge(listed_in)
show_listed_in = show_listed_in.drop(columns="listed_in")
show_listed_in
# Out:
#         show_id  listed_in_id
# 0      81145628             1
# 1      80182480             1
# 2      80182483             1
# 3      80182596             1
# 4      80182482             1
# ...         ...           ...
# 13665  80023876            42
# 13666  70142437            42
# 13667  70140450            42
# 13668  70153412            42
# 13669  70153404            42
#
# [13670 rows x 2 columns]

# %%
#Dataframes pour director & catalog_director
#22.A. Faire de même avec les colonnes director en créant des dataframe qui leur sont dédier.

netflix2 = netflix[['director']].dropna().reset_index()

show_nom_director = pd.DataFrame(columns = ['nom_director','show_id'])

for i in netflix2.index:
  
    director_ = netflix2["director"][i].split(", ")
    show_id =[netflix2["index"][i]] * len(director_)
    df = pd.DataFrame({'nom_director': director_ ,'show_id': show_id})
    show_nom_director = show_nom_director.append(df, ignore_index=True)

show_nom_director
# Out:
#               nom_director show_id
# 0             Richard Finn       0
# 1               Tim Maltby       0
# 2         Fernando Lebrija       4
# 3              Gabe Ibáñez       6
# 4             Rodrigo Toro       7
# ...                    ...     ...
# 4847         Thomas Astruc    6158
# 4848  Vikramaditya Motwane    6167
# 4849        Anurag Kashyap    6167
# 4850            Jung-ah Im    6182
# 4851             Onur Ünlü    6213
#
# [4852 rows x 2 columns]

# %%
#22. Créez un dataframe nommé « director » ayant pour colonne « nom_director » et « director_id ».

directors = pd.DataFrame(columns = ['director_id'])
directors['nom_director'] = show_nom_director['nom_director'].drop_duplicates()
directors.reset_index(drop= True, inplace = True)
directors['director_id'] = directors.index + 1
directors
# Out:
#       director_id      nom_director
# 0               1      Richard Finn
# 1               2        Tim Maltby
# 2               3  Fernando Lebrija
# 3               4       Gabe Ibáñez
# 4               5      Rodrigo Toro
# ...           ...               ...
# 3650         3651       James Hawes
# 3651         3652        Jung-ah Im
# 3652         3653       Seung-uk Jo
# 3653         3654   Andy Devonshire
# 3654         3655         Onur Ünlü
#
# [3655 rows x 2 columns]

# %%
show_nom_director = show_nom_director.merge(director)
show_nom_director = show_nom_director.drop(columns="nom_director")
show_nom_director
# Out:
#      show_id  director_id
# 0          0            0
# 1          0            1
# 2       1780            1
# 3          4            2
# 4          6            3
# ...      ...          ...
# 4847    6134         3651
# 4848    6182         3651
# 4849    6134         3652
# 4850    6142         3653
# 4851    6213         3654
#
# [4852 rows x 2 columns]

# %%
show_nom_director = show_nom_director.drop_duplicates()
show_nom_director
# Out:
#      show_id  director_id
# 0          0            0
# 1          0            1
# 2       1780            1
# 3          4            2
# 4          6            3
# ...      ...          ...
# 4847    6134         3651
# 4848    6182         3651
# 4849    6134         3652
# 4850    6142         3653
# 4851    6213         3654
#
# [4851 rows x 2 columns]

# %%
#Dataframes pour actor & catalog_actor
#22.B. Créez un dataframe nommé « cast » ayant pour colonne « nom_cast » et « show_id ».

actordf = netflix[netflix['cast'].notna()][['show_id', 'cast']]
show_actors = pd.DataFrame(columns = ['show_id','actor_name'])

for i in actordf.index:
    acteursFilm = actordf["cast"][i].split(", ") 
    idActeur = [actordf["show_id"][i]] * len(acteursFilm)
    df = pd.DataFrame({'show_id': idActeur,'actor_name': acteursFilm})
    show_actors = show_actors.append(df, ignore_index = True)
              
show_actors
# Out:
#         show_id        actor_name
# 0      81145628     Alan Marriott
# 1      81145628       Andrew Toth
# 2      81145628      Brian Dobson
# 3      81145628       Cole Howard
# 4      81145628  Jennifer Cameron
# ...         ...               ...
# 44305  70153404     Courteney Cox
# 44306  70153404       Lisa Kudrow
# 44307  70153404      Matt LeBlanc
# 44308  70153404     Matthew Perry
# 44309  70153404   David Schwimmer
#
# [44310 rows x 2 columns]

# %%
actors = pd.DataFrame(columns = ['actor_id','actor_name'])
actors['actor_name'] = show_actors['actor_name'].drop_duplicates()
actors.reset_index(drop= True, inplace = True)
actors['actor_id'] = actors.index + 1
actors
# Out:
#        actor_id        actor_name
# 0             1     Alan Marriott
# 1             2       Andrew Toth
# 2             3      Brian Dobson
# 3             4       Cole Howard
# 4             5  Jennifer Cameron
# ...         ...               ...
# 27399     27400   Rosie Cavaliero
# 27400     27401  Vicki Pepperdine
# 27401     27402   Margaret Clunie
# 27402     27403         Tim Steed
# 27403     27404     Matthew Perry
#
# [27404 rows x 2 columns]

# %%
show_actors = show_actors.merge(actors)
show_actors = show_actors.drop(columns="actor_name")
show_actors
# Out:
#         show_id  actor_id
# 0      81145628         1
# 1      81065331         1
# 2      70109891         1
# 3      81145628         2
# 4      80191075         2
# ...         ...       ...
# 44305  70281022     27400
# 44306  70281022     27401
# 44307  70281022     27402
# 44308  70281022     27403
# 44309  70153404     27404
#
# [44310 rows x 2 columns]

# %%
show_actors = show_actors.drop_duplicates()
show_actors
# Out:
#         show_id  actor_id
# 0      81145628         1
# 1      81065331         1
# 2      70109891         1
# 3      81145628         2
# 4      80191075         2
# ...         ...       ...
# 44305  70281022     27400
# 44306  70281022     27401
# 44307  70281022     27402
# 44308  70281022     27403
# 44309  70153404     27404
#
# [44309 rows x 2 columns]

# %%
#22.C. Dataframes pour country & catalog_country

paysdf = netflix[netflix['country'].notna()][['show_id', 'country']]
show_countries = pd.DataFrame(columns = ['show_id','country_name'])

for i in paysdf.index:
    paysFilm = paysdf["country"][i].split(", ") 
    idPays = [paysdf["show_id"][i]] * len(paysFilm)
    df = pd.DataFrame({'show_id': idPays,'country_name': paysFilm})
    show_countries = show_countries.append(df, ignore_index = True)
              
show_countries
# Out:
#        show_id    country_name
# 0     81145628   United States
# 1     81145628           India
# 2     81145628     South Korea
# 3     81145628           China
# 4     80117401  United Kingdom
# ...        ...             ...
# 7174  80005756       Australia
# 7175  80000063   United States
# 7176  70286564   United States
# 7177  70281022  United Kingdom
# 7178  70153404   United States
#
# [7179 rows x 2 columns]

# %%
countries = pd.DataFrame(columns = ['country_id','country_name'])
countries['country_name'] = show_countries['country_name'].drop_duplicates()
countries.reset_index(drop= True, inplace = True)
countries['country_id'] = countries.index + 1
countries
# Out:
#      country_id    country_name
# 0             1   United States
# 1             2           India
# 2             3     South Korea
# 3             4           China
# 4             5  United Kingdom
# ..          ...             ...
# 108         109         Bermuda
# 109         110         Ecuador
# 110         111           Syria
# 111         112          Kuwait
# 112         113          Cyprus
#
# [113 rows x 2 columns]

# %%
show_countries = show_countries.merge(countries)
show_countries = show_countries.drop(columns="country_name")
show_countries
# Out:
#        show_id  country_id
# 0     81145628           1
# 1     70234439           1
# 2     80058654           1
# 3     80125979           1
# 4     70304989           1
# ...        ...         ...
# 7174  70308278         109
# 7175  70308278         110
# 7176  80217848         111
# 7177  80217848         112
# 7178  80162994         113
#
# [7179 rows x 2 columns]

# %%
#Supprimer les colonnes listed_id, director et cast
netflix2 = netflix.drop(columns=['listed_in', 'director', 'cast', 'country'])
netflix2.date_added = pd.to_datetime(netflix2.date_added)
netflix2.duration = netflix2.duration.str.replace(" min", "").str.replace(" Seasons", "").str.replace(" Season", "")
netflix2.duration = netflix2.duration.astype('int')
netflix2
# Out:
#        show_id     type                                        title  \
# 0     81145628    Movie      Norm of the North: King Sized Adventure
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 2     70234439  TV Show                           Transformers Prime
# 3     80058654  TV Show             Transformers: Robots in Disguise
# 4     80125979    Movie                                 #realityhigh
# ...        ...      ...                                          ...
# 6229  80000063  TV Show                                 Red vs. Blue
# 6230  70286564  TV Show                                        Maron
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  70153404  TV Show                                      Friends
#
#      date_added  release_year    rating  duration  \
# 0    2019-09-09          2019     TV-PG        90
# ...

# %%
#Intégration des DataFrames dans MySQL
#23. Intégrez les dataframes dans la base de données structuré.

from sqlalchemy import create_engine

engine = create_engine('mysql+pymysql://luca:pelliccoli@localhost:3306/netflix', echo=True)

# %%
countries.rename(columns={'country_id' : 'COUNTRY_ID', 'country_name' : 'COUNTRY_NAME'}).to_sql('country', con=engine, index = False, if_exists = 'append')
# Out:
# 2020-09-16 16:52:56,753 INFO sqlalchemy.engine.base.Engine DESCRIBE `country`
# 2020-09-16 16:52:56,754 INFO sqlalchemy.engine.base.Engine {}
# 2020-09-16 16:52:56,756 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-09-16 16:52:56,758 INFO sqlalchemy.engine.base.Engine INSERT INTO country (`COUNTRY_ID`, `COUNTRY_NAME`) VALUES (%(COUNTRY_ID)s, %(COUNTRY_NAME)s)
# 2020-09-16 16:52:56,758 INFO sqlalchemy.engine.base.Engine ({'COUNTRY_ID': 1, 'COUNTRY_NAME': 'United States'}, {'COUNTRY_ID': 2, 'COUNTRY_NAME': 'India'}, {'COUNTRY_ID': 3, 'COUNTRY_NAME': 'South Korea'}, {'COUNTRY_ID': 4, 'COUNTRY_NAME': 'China'}, {'COUNTRY_ID': 5, 'COUNTRY_NAME': 'United Kingdom'}, {'COUNTRY_ID': 6, 'COUNTRY_NAME': 'Spain'}, {'COUNTRY_ID': 7, 'COUNTRY_NAME': 'Bulgaria'}, {'COUNTRY_ID': 8, 'COUNTRY_NAME': 'Canada'}  ... displaying 10 of 113 total bound parameter sets ...  {'COUNTRY_ID': 112, 'COUNTRY_NAME': 'Kuwait'}, {'COUNTRY_ID': 113, 'COUNTRY_NAME': 'Cyprus'})
# ...

# %%
listed_in.rename(columns={'listed_in_id' : 'CATEGORY_ID', 'listed_in' : 'CATEGORY_NAME'}).to_sql('category', con=engine, index = False, if_exists = 'append')
# Out:
# 2020-09-16 16:53:15,735 INFO sqlalchemy.engine.base.Engine DESCRIBE `category`
# 2020-09-16 16:53:15,737 INFO sqlalchemy.engine.base.Engine {}
# 2020-09-16 16:53:15,741 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-09-16 16:53:15,743 INFO sqlalchemy.engine.base.Engine INSERT INTO category (`CATEGORY_ID`, `CATEGORY_NAME`) VALUES (%(CATEGORY_ID)s, %(CATEGORY_NAME)s)
# ...

# %%
directors.rename(columns={'nom_director' : 'DIRECTOR_NAME'}).to_sql('director', con=engine, if_exists='append', index=False)
# Out:
# 2020-09-16 16:53:27,651 INFO sqlalchemy.engine.base.Engine DESCRIBE `director`
# 2020-09-16 16:53:27,654 INFO sqlalchemy.engine.base.Engine {}
# 2020-09-16 16:53:27,658 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-09-16 16:53:27,904 INFO sqlalchemy.engine.base.Engine INSERT INTO director (director_id, `DIRECTOR_NAME`) VALUES (%(director_id)s, %(DIRECTOR_NAME)s)
# ...

# %%
actors.rename(columns={'actor_id' : 'CAST_ID', 'actor_name' : 'CAST_name'}).to_sql('cast', con=engine, if_exists='append', index=False)
# Out:
# 2020-09-16 16:53:33,310 INFO sqlalchemy.engine.base.Engine DESCRIBE `cast`
# 2020-09-16 16:53:33,311 INFO sqlalchemy.engine.base.Engine {}
# 2020-09-16 16:53:33,319 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-09-16 16:53:33,461 INFO sqlalchemy.engine.base.Engine INSERT INTO cast (`CAST_ID`, `CAST_name`) VALUES (%(CAST_ID)s, %(CAST_name)s)
# 2020-09-16 16:53:33,463 INFO sqlalchemy.engine.base.Engine ({'CAST_ID': 1, 'CAST_name': 'Alan Marriott'}, {'CAST_ID': 2, 'CAST_name': 'Andrew Toth'}, {'CAST_ID': 3, 'CAST_name': 'Brian Dobson'}, {'CAST_ID': 4, 'CAST_name': 'Cole Howard'}, {'CAST_ID': 5, 'CAST_name': 'Jennifer Cameron'}, {'CAST_ID': 6, 'CAST_name': 'Jonathan Holmes'}, {'CAST_ID': 7, 'CAST_name': 'Lee Tockar'}, {'CAST_ID': 8, 'CAST_name': 'Lisa Durupt'}  ... displaying 10 of 27404 total bound parameter sets ...  {'CAST_ID': 27403, 'CAST_name': 'Tim Steed'}, {'CAST_ID': 27404, 'CAST_name': 'Matthew Perry'})
# ...

# %%
netflix2.to_sql('catalog', con=engine, if_exists='append', index=False)
# Out:
# 2020-09-16 16:53:38,598 INFO sqlalchemy.engine.base.Engine DESCRIBE `catalog`
# 2020-09-16 16:53:38,599 INFO sqlalchemy.engine.base.Engine {}
# 2020-09-16 16:53:38,605 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-09-16 16:53:38,688 INFO sqlalchemy.engine.base.Engine INSERT INTO catalog (show_id, type, title, date_added, release_year, rating, duration, description) VALUES (%(show_id)s, %(type)s, %(title)s, %(date_added)s, %(release_year)s, %(rating)s, %(duration)s, %(description)s)
# ...

# %%
show_actors.rename(columns={'show_id' : 'SHOW_ID_FK', 'actor_id' : 'CAST_ID_FK'}).to_sql('catalog_cast', con=engine, if_exists='append', index=False)
# Out:
# 2020-09-16 16:53:51,606 INFO sqlalchemy.engine.base.Engine DESCRIBE `catalog_cast`
# 2020-09-16 16:53:51,606 INFO sqlalchemy.engine.base.Engine {}
# 2020-09-16 16:53:51,613 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-09-16 16:53:51,993 INFO sqlalchemy.engine.base.Engine INSERT INTO catalog_cast (`SHOW_ID_FK`, `CAST_ID_FK`) VALUES (%(SHOW_ID_FK)s, %(CAST_ID_FK)s)
# 2020-09-16 16:53:51,993 INFO sqlalchemy.engine.base.Engine ({'SHOW_ID_FK': 81145628, 'CAST_ID_FK': 1}, {'SHOW_ID_FK': 81065331, 'CAST_ID_FK': 1}, {'SHOW_ID_FK': 70109891, 'CAST_ID_FK': 1}, {'SHOW_ID_FK': 81145628, 'CAST_ID_FK': 2}, {'SHOW_ID_FK': 80191075, 'CAST_ID_FK': 2}, {'SHOW_ID_FK': 81065331, 'CAST_ID_FK': 2}, {'SHOW_ID_FK': 81145628, 'CAST_ID_FK': 3}, {'SHOW_ID_FK': 70204970, 'CAST_ID_FK': 3}  ... displaying 10 of 44309 total bound parameter sets ...  {'SHOW_ID_FK': 70281022, 'CAST_ID_FK': 27403}, {'SHOW_ID_FK': 70153404, 'CAST_ID_FK': 27404})
# ...

# %%
show_listed_in.rename(columns={'listed_in_id' : 'CATALOGUE_ID_FK', 'show_id' : 'SHOW_ID_FK'}).to_sql('catalog_category', con=engine, if_exists='append', index=False)
# Out:
# 2020-09-16 16:54:02,334 INFO sqlalchemy.engine.base.Engine DESCRIBE `catalog_category`
# 2020-09-16 16:54:02,336 INFO sqlalchemy.engine.base.Engine {}
# 2020-09-16 16:54:02,339 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-09-16 16:54:02,413 INFO sqlalchemy.engine.base.Engine INSERT INTO catalog_category (`SHOW_ID_FK`, `CATALOGUE_ID_FK`) VALUES (%(SHOW_ID_FK)s, %(CATALOGUE_ID_FK)s)
# ...

# %%
show_countries.rename(columns={'show_id' : 'SHOW_ID_FK', 'country_id' : 'COUNTRY_ID_FK'}).to_sql('country_catalog', con=engine, if_exists='append', index=False)
# Out:
# 2020-09-16 16:54:10,142 INFO sqlalchemy.engine.base.Engine DESCRIBE `country_catalog`
# 2020-09-16 16:54:10,143 INFO sqlalchemy.engine.base.Engine {}
# 2020-09-16 16:54:10,148 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-09-16 16:54:10,209 INFO sqlalchemy.engine.base.Engine INSERT INTO country_catalog (`SHOW_ID_FK`, `COUNTRY_ID_FK`) VALUES (%(SHOW_ID_FK)s, %(COUNTRY_ID_FK)s)
# 2020-09-16 16:54:10,210 INFO sqlalchemy.engine.base.Engine ({'SHOW_ID_FK': 81145628, 'COUNTRY_ID_FK': 1}, {'SHOW_ID_FK': 70234439, 'COUNTRY_ID_FK': 1}, {'SHOW_ID_FK': 80058654, 'COUNTRY_ID_FK': 1}, {'SHOW_ID_FK': 80125979, 'COUNTRY_ID_FK': 1}, {'SHOW_ID_FK': 70304989, 'COUNTRY_ID_FK': 1}, {'SHOW_ID_FK': 80117902, 'COUNTRY_ID_FK': 1}, {'SHOW_ID_FK': 70304990, 'COUNTRY_ID_FK': 1}, {'SHOW_ID_FK': 70299204, 'COUNTRY_ID_FK': 1}  ... displaying 10 of 7179 total bound parameter sets ...  {'SHOW_ID_FK': 80217848, 'COUNTRY_ID_FK': 112}, {'SHOW_ID_FK': 80162994, 'COUNTRY_ID_FK': 113})
# ...

# %%
show_nom_director.rename(columns={'show_id' : 'SHOW_ID_FK', 'director_id' : 'DIRECTOR_ID_FK'}).drop_duplicates().to_sql('director_catalog', con=engine, if_exists='append', index=False)
# Out:
# 2020-09-16 16:54:19,432 INFO sqlalchemy.engine.base.Engine DESCRIBE `director_catalog`
# 2020-09-16 16:54:19,432 INFO sqlalchemy.engine.base.Engine {}
# 2020-09-16 16:54:19,438 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-09-16 16:54:19,646 INFO sqlalchemy.engine.base.Engine INSERT INTO director_catalog (`SHOW_ID_FK`, `DIRECTOR_ID_FK`) VALUES (%(SHOW_ID_FK)s, %(DIRECTOR_ID_FK)s)
# 2020-09-16 16:54:19,647 INFO sqlalchemy.engine.base.Engine ({'SHOW_ID_FK': 0, 'DIRECTOR_ID_FK': 0}, {'SHOW_ID_FK': 0, 'DIRECTOR_ID_FK': 1}, {'SHOW_ID_FK': 1780, 'DIRECTOR_ID_FK': 1}, {'SHOW_ID_FK': 4, 'DIRECTOR_ID_FK': 2}, {'SHOW_ID_FK': 6, 'DIRECTOR_ID_FK': 3}, {'SHOW_ID_FK': 7, 'DIRECTOR_ID_FK': 4}, {'SHOW_ID_FK': 7, 'DIRECTOR_ID_FK': 5}, {'SHOW_ID_FK': 9, 'DIRECTOR_ID_FK': 6}  ... displaying 10 of 4851 total bound parameter sets ...  {'SHOW_ID_FK': 6142, 'DIRECTOR_ID_FK': 3653}, {'SHOW_ID_FK': 6213, 'DIRECTOR_ID_FK': 3654})
# ...
